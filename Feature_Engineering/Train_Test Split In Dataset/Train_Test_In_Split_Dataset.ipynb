# %%
import pandas as pd

# %%
dataset=pd.read_csv("/content/d4332a3056f44e1a1dec9600a31f21c8_boston.csv")
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  House_Price
# 0       15.3         24.0
# 1       17.8         21.6
# 2       17.8         34.7
# 3       18.7         33.4
# 4       18.7         36.2
# ..       ...          ...
# 501     21.0         22.4
# 502     21.0         20.6
# 503     21.0         23.9
# 504     21.0         22.0
# 505     21.0         19.0
#
# [506 rows x 12 columns]

# %%
dataset.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#    House_Price
# 0         24.0
# 1         21.6
# 2         34.7

# %%
dataset.shape
# Out:
# (506, 12)

# %%
input_data=dataset.iloc[:,:-1]
output_data=dataset['House_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(input_data, output_data, test_size=0.25)

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 105   0.13262   0.0   8.56     0  0.520  5.851   96.7  2.1069    5  384
# 307   0.04932  33.0   2.18     0  0.472  6.849   70.3  3.1827    7  222
# 344   0.03049  55.0   3.78     0  0.484  6.874   28.1  6.4654    5  370
# 46    0.18836   0.0   6.91     0  0.448  5.786   33.3  5.1004    3  233
# 266   0.78570  20.0   3.97     0  0.647  7.014   84.6  2.1329    5  264
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 165   2.92400   0.0  19.58     0  0.605  6.101   93.0  2.2834    5  403
# 34    1.61282   0.0   8.14     0  0.538  6.096   96.9  3.7598    4  307
# 69    0.12816  12.5   6.07     0  0.409  5.885   33.0  6.4980    4  345
# 407  11.95110   0.0  18.10     0  0.659  5.608  100.0  1.2852   24  666
#
#      PTRATIO
# 105     20.9
# 307     18.4
# 344     17.6
# 46      17.9
# 266     13.0
# ..       ...
# 3       18.7
# 165     14.7
# 34      21.0
# 69      18.9
# 407     20.2
#
# [379 rows x 11 columns]

# %%
x_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 27   0.95577   0.0   8.14     0  0.538  6.047  88.8  4.4534    4  307     21.0
# 466  3.77498   0.0  18.10     0  0.655  5.952  84.7  2.8715   24  666     20.2
# 154  1.41385   0.0  19.58     1  0.871  6.129  96.0  1.7494    5  403     14.7
# 243  0.12757  30.0   4.93     0  0.428  6.393   7.8  7.0355    6  300     16.6
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 225  0.52693   0.0   6.20     0  0.504  8.725  83.0  2.8944    8  307     17.4
# 362  3.67822   0.0  18.10     0  0.770  5.362  96.2  2.1036   24  666     20.2
# 356  8.98296   0.0  18.10     1  0.770  6.212  97.4  2.1222   24  666     20.2
# 51   0.04337  21.0   5.64     0  0.439  6.115  63.0  6.8147    4  243     16.8
# 233  0.33147   0.0   6.20     0  0.507  8.247  70.4  3.6519    8  307     17.4
#
# [127 rows x 11 columns]

# %%
y_train
# Out:
# 105    19.5
# 307    28.2
# 344    31.2
# 46     20.0
# 266    30.7
#        ...
# 3      33.4
# 165    25.0
# 34     13.5
# 69     20.9
# 407    27.9
# Name: House_Price, Length: 379, dtype: float64

# %%
y_test
# Out:
# 27     14.8
# 466    19.0
# 154    17.0
# 243    23.7
# 4      36.2
#        ...
# 225    50.0
# 362    20.8
# 356    17.8
# 51     20.5
# 233    48.3
# Name: House_Price, Length: 127, dtype: float64

# %%
x_train.shape, y_train.shape
# Out:
# ((379, 11), (379,))

# %%
x_test.shape, y_test.shape
# Out:
# ((127, 11), (127,))
